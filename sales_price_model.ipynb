# %% [markdown]
# # This is the small project  demo for machine learning workshop (entry level)
#
# Athensoft & Candata present
#
# correspondence: ymnie888@gmail.com

# %% [markdown]
# ## 1. import libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## 2. load data set

# %%
DATA_PATH = 'C:\\Users\\ymnie\\Dropbox (SITEM)\\Candata\\sitem\\workshop\\data\\'

# %%
train = pd.read_csv(DATA_PATH+'sale_price.csv')
print(train.shape)
train.head(2)
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %% [markdown]
# ## 3. data preprocessing & analysis

# %%
# extract target variable
train_y = np.log1p(train['SalePrice'])

# %%
train_y
# Out:
# 0       12.247699
# 1       12.109016
# 2       12.317171
# 3       11.849405
# 4       12.429220
# 5       11.870607
# 6       12.634606
# 7       12.206078
# 8       11.774528
# 9       11.678448
# 10      11.771444
# 11      12.751303
# 12      11.877576
# 13      12.540761
# 14      11.964007
# 15      11.790565
# 16      11.911708
# 17      11.407576
# 18      11.976666
# 19      11.842236
# 20      12.692506
# 21      11.845110
# 22      12.345839
# 23      11.774528
# 24      11.944714
# 25      12.454108
# 26      11.811555
# 27      12.631344
# 28      12.242891
# 29      11.134604
#           ...
# 1430    12.165985
# 1431    11.875838
# 1432    11.074436
# 1433    12.136192
# 1434    11.982935
# 1435    12.066816
# 1436    11.699413
# 1437    12.885673
# 1438    11.916395
# 1439    12.190964
# 1440    12.160034
# 1441    11.913720
# 1442    12.644331
# 1443    11.703554
# 1444    12.098493
# 1445    11.767575
# 1446    11.969724
# 1447    12.388398
# 1448    11.626263
# ...

# %%
# extract all features that will be used for training or selection
features = [f for f in train.columns if f not in ['Id','SalePrice']]
print(len(features))
print(features)
# Out:
# 79
# ...

# %%
# or you can drop unused cols to save memory
drop_cols = ['Id','SalePrice']
train_X = train.drop(drop_cols,axis=1)

# %%
# extract train_X which is separated from target!! be careful. this should not contain target variable anymore
# train_X = train[features]
# print(train_X.shape)

# %%
#check all data types
data_types = train_X.dtypes.unique()
print(data_types)
# Out:
# [dtype('int64') dtype('O') dtype('float64')]

# %%
train_X.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
#                   ...
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# ...

# %%
# get all categorical and numerical features(columns)
cal_cols = [f for f in train_X.columns if train_X[f].dtypes == 'object']
num_cols = [f for f in train_X.columns if ('float' in str(train_X[f].dtypes)) or ('int' in str(train_X[f].dtypes))]
print(cal_cols)
print('---------------------------------------------------------------')
print(num_cols)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
# ---------------------------------------------------------------
# ...

# %%
train_X.isnull().sum()/len(train_X)
# Out:
# MSSubClass       0.000000
# MSZoning         0.000000
# LotFrontage      0.177397
# LotArea          0.000000
# Street           0.000000
# Alley            0.937671
# LotShape         0.000000
# LandContour      0.000000
# Utilities        0.000000
# LotConfig        0.000000
# LandSlope        0.000000
# Neighborhood     0.000000
# Condition1       0.000000
# Condition2       0.000000
# BldgType         0.000000
# HouseStyle       0.000000
# OverallQual      0.000000
# OverallCond      0.000000
# YearBuilt        0.000000
# YearRemodAdd     0.000000
# RoofStyle        0.000000
# RoofMatl         0.000000
# Exterior1st      0.000000
# Exterior2nd      0.000000
# MasVnrType       0.005479
# MasVnrArea       0.005479
# ExterQual        0.000000
# ExterCond        0.000000
# Foundation       0.000000
# BsmtQual         0.025342
#                    ...
# HalfBath         0.000000
# BedroomAbvGr     0.000000
# KitchenAbvGr     0.000000
# KitchenQual      0.000000
# ...

# %%
null_data = pd.DataFrame(train_X.isnull().sum()/len(train_X)).reset_index()
null_data.columns = ['col_name','null_ratio']
null_data.sort_values(by='null_ratio',ascending=False,inplace=True)
null_data
# Out:
#          col_name  null_ratio
# 71         PoolQC    0.995205
# 73    MiscFeature    0.963014
# 5           Alley    0.937671
# 72          Fence    0.807534
# 56    FireplaceQu    0.472603
# 2     LotFrontage    0.177397
# 57     GarageType    0.055479
# 58    GarageYrBlt    0.055479
# 62     GarageQual    0.055479
# 63     GarageCond    0.055479
# 59   GarageFinish    0.055479
# 34   BsmtFinType2    0.026027
# 31   BsmtExposure    0.026027
# 30       BsmtCond    0.025342
# 32   BsmtFinType1    0.025342
# 29       BsmtQual    0.025342
# 25     MasVnrArea    0.005479
# 24     MasVnrType    0.005479
# 41     Electrical    0.000685
# 50   BedroomAbvGr    0.000000
# 47   BsmtHalfBath    0.000000
# 48       FullBath    0.000000
# 51   KitchenAbvGr    0.000000
# 49       HalfBath    0.000000
# 54     Functional    0.000000
# 55     Fireplaces    0.000000
# 52    KitchenQual    0.000000
# 53   TotRmsAbvGrd    0.000000
# 0      MSSubClass    0.000000
# 45      GrLivArea    0.000000
# ...

# %%
# do some analysis to see if data contains null values and calculate the ratio of how many null values are in each col
null_data = pd.DataFrame(train_X.isnull().sum()/len(train_X)).reset_index()
null_data.columns = ['col_name','null_ratio']
null_data.sort_values(by='null_ratio',ascending=False,inplace=True)
null_data.loc[null_data.null_ratio>0]

# %%
drop_cols = null_data.loc[null_data['null_ratio']>0.4]['col_name'].values
drop_cols
# Out:
# array(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu'],
#       dtype=object)

# %%
train_X.drop(drop_cols,axis=1,inplace=True)

# %%
train_X.shape
# Out:
# (1460, 74)

# %%
# train_X.PoolQC.unique()

# %%
cal_cols = [f for f in cal_cols if f not in drop_cols]
num_cols = [f for f in num_cols if f not in drop_cols]

# %%
for f in cal_cols:
    train_X[f] = train_X[f].fillna('unknown')
    
for f in num_cols:
    train_X[f] = train_X[f].fillna(train_X[f].mean())

# %%
# # fill nan number
# for i,f in enumerate(cal_cols):
# #     if i%10==0:
# #         print('processing {} cols'.format(i+1))
#     train_X[f] = train[f].fillna('unknown').astype('category')

# for i,f in enumerate(num_cols):
# #     if i%10==0:
# #         print('processing {} cols'.format(i+1))
#     train_X[f] = train[f].fillna(train[f].mean())

# %%
train_X.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope      ...      OpenPorchSF EnclosedPorch  \
# 0    AllPub    Inside       Gtl      ...               61             0
# 1    AllPub       FR2       Gtl      ...                0             0
# 2    AllPub    Inside       Gtl      ...               42             0
# 3    AllPub    Corner       Gtl      ...               35           272
# 4    AllPub       FR2       Gtl      ...               84             0
#
#   3SsnPorch ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
train_X[num_cols].head()

# %% [markdown]
# ### so far we did minimal effort on data cleaning and we then need to convert all categorical variables to dummy variables

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
# le.fit_transform(['I','like','this','book']) #this is like dummy variables!!

# %%
for f in cal_cols:
    train_X[f] = le.fit_transform(train_X[f])

# %%
train_X.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          60         3         65.0     8450       1         3            3
# 1          20         3         80.0     9600       1         3            3
# 2          60         3         68.0    11250       1         0            3
# 3          70         3         60.0     9550       1         0            3
# 4          60         3         84.0    14260       1         0            3
#
#    Utilities  LotConfig  LandSlope      ...        OpenPorchSF  EnclosedPorch  \
# 0          0          4          0      ...                 61              0
# 1          0          2          0      ...                  0              0
# 2          0          4          0      ...                 42              0
# 3          0          0          0      ...                 35            272
# 4          0          2          0      ...                 84              0
#
# ...

# %%
train_X.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
#new features
# total_house_areas = LotArea + PoolArea+....

# %%
corr_df = pd.DataFrame(train_X.corrwith(train_y)).reset_index()
corr_df.columns = ['cols','corr_coeff']
corr_df.sort_values('corr_coeff',ascending=False,inplace=True)
corr_df.head(10)

# %%
train_X[corr_df.head(10).cols].head()

# %%
train_X[num_cols].columns

# %%
corr_df.tail(10)

# %%
# sns.barplot(corr_df.corr_coeff,corr_df.cols)

# %%
# corr_df

# %% [markdown]
# # 4. Model selection, API load

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
# from sklearn.ensemble import AdaBoostRegressor
# from sklearn.linear_model import Ridge

from sklearn.model_selection import train_test_split,KFold
from sklearn.metrics import mean_squared_error

# %%
def train_model(train_X,train_y,model_name):
    kf = KFold(n_splits=5,random_state=2018,shuffle=True)
    scores = []
    folds = kf.split(train_X)
    for i,(train_idx,valid_idx) in enumerate(folds):
        print('processing {}th fold'.format(i+1))
        tr_X = train_X.loc[train_idx]
        tr_y = train_y[train_idx]
        va_X = train_X.loc[valid_idx]
        va_y = train_y[valid_idx]
        
        
        if model_name == 'rf':
            model = load_rf()
        if model_name == 'gbt':
            model = load_gbt()
        model_rf = RandomForestRegressor(n_estimators=np.random.randint(100,500),
#                                          max_depth=np.random.randint(10,20),
                                         random_state = np.random.randint(1000000),
                                         n_jobs=-1
                                        )
        model_rf.fit(tr_X,tr_y)
        pred_y_val = model_rf.predict(va_X)
        curr_score = mean_squared_error(va_y,pred_y_val)
        scores.append(curr_score)
        print('...... current valuation score in this fold is: {}'.format(curr_score))

# %%
kf = KFold(n_splits=5,random_state=2018,shuffle=True)

# %%
scores = []
folds = kf.split(train_X)
for i,(train_idx,valid_idx) in enumerate(folds):
    print('processing {}th fold'.format(i+1))
    tr_X = train_X.loc[train_idx]
    tr_y = train_y[train_idx]
    va_X = train_X.loc[valid_idx]
    va_y = train_y[valid_idx]
    
    model_rf = RandomForestRegressor(n_estimators=np.random.randint(100,500),
                                     max_depth=np.random.randint(10,20),
                                     random_state = np.random.randint(1000000),
                                     n_jobs=-1
                                    )
    model_rf.fit(tr_X,tr_y)
    pred_y_val = model_rf.predict(va_X)
    curr_score = mean_squared_error(va_y,pred_y_val)
    scores.append(curr_score)
    print('...... current valuation score in this fold is: {}'.format(curr_score))
# Out:
# processing 1th fold
# ...... current valuation score in this fold is: 0.023143004369792036
# processing 2th fold
# ...... current valuation score in this fold is: 0.015179973061261419
# processing 3th fold
# ...... current valuation score in this fold is: 0.02125929836004841
# processing 4th fold
# ...... current valuation score in this fold is: 0.025507400680099736
# processing 5th fold
# ...... current valuation score in this fold is: 0.01730788707864775

# %%
np.mean(scores)

# %% [markdown]
# # Some feature engineering

# %%
print(num_cols)

# %%
train_X['tol_area'] = train_X.LotArea+train_X.GrLivArea +train_X.GarageArea+train_X.PoolArea
train_X['ratio_bsmt'] = train_X.BsmtFullBath+train_X.BsmtHalfBath
train_X['tol_porch'] = train_X.OpenPorchSF+train_X.EnclosedPorch+train_X['3SsnPorch']+train_X['ScreenPorch']
train_X['diff_build_remode'] = train_X.YearBuilt - train_X.YearRemodAdd
train_X['diff_build_sold'] = train_X.YearBuilt - train_X.YrSold
train_X['x'] =  train_X['tol_area'] - train_X['LowQualFinSF'] 
train_X['x1'] = train_X['1stFlrSF']+train_X['2ndFlrSF']  # good feature

# %%
train_X.drop('x1',axis=1,inplace=True)

# %%
scores = []
folds = kf.split(train_X)
for i,(train_idx,valid_idx) in enumerate(folds):
    print('processing {}th fold'.format(i+1))
    tr_X = train_X.loc[train_idx]
    tr_y = train_y[train_idx]
    va_X = train_X.loc[valid_idx]
    va_y = train_y[valid_idx]
    
    model_rf = RandomForestRegressor(n_estimators=np.random.randint(100,500),
                                     max_depth=np.random.randint(10,20),
                                     random_state = np.random.randint(1000000),
                                     n_jobs=-1
                                    )
    model_rf.fit(tr_X,tr_y)
    pred_y_val = model_rf.predict(va_X)
    curr_score = mean_squared_error(va_y,pred_y_val)
    scores.append(curr_score)
    print('...... current valuation score in this fold is: {}'.format(curr_score))

# %%
np.mean(scores)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import f1_score

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
